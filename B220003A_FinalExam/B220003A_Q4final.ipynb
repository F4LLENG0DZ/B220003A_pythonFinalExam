# %%
import pandas as pd

# %%
df = pd.read_csv('happy.csv')
df
# Out:
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

gdp_sorted_df = df.sort_values(by = 'Log GDP per capita', ascending=True)
gen_sorted_df = df.sort_values(by = 'Generosity', ascending=True)

x = gdp_sorted_df['Log GDP per capita'].query("'Regional indicator' == Western Europe")
y = gen_sorted_df['Generosity'].query("'Regional indicator' == Western Europe")

fig, ax = plt.subplots()
ax.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2428\3566631625.py in ?()
#       3
#       4 gdp_sorted_df = df.sort_values(by = 'Log GDP per capita', ascending=True)
#       5 gen_sorted_df = df.sort_values(by = 'Generosity', ascending=True)
#       6
# ----> 7 x = gdp_sorted_df['Log GDP per capita'].query("'Regional indicator' == Western Europe")
#       8 y = gen_sorted_df['Generosity'].query("'Regional indicator' == Western Europe")
#       9
#      10 fig, ax = plt.subplots()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# ...
